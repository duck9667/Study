# %% [markdown]
# # Crawling

# %% [markdown]
# ### 1. API 활용방법
# https://developers.google.com/youtube/v3/docs/search?hl=ko

# %%
pip install apiclient
pip install oauth2client
pip install --upgrade google-api-python-client

# ERROR: streamlit 0.57.3 requires altair>=3.2.0, which is not installed.
# ERROR: streamlit 0.57.3 requires astor, which is not installed.
# ERROR: streamlit 0.57.3 requires blinker, which is not installed.
# ERROR: streamlit 0.57.3 has requirement tornado<6.0,>=5.0, but you'll have tornado 6.0.3 which is incompatible.

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyBO1YbOUzcVYhf9GQRLAGKvSITPq7DmHQc"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# build(googleapiclient.discovery) 객체 생성
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey = DEVELOPER_KEY)

# 검색결과 크롤링
search_response = youtube.search().list(
    q = "bts",
    pageToken = 'CDIQAA',
    order = "date",
    part = "snippet",
    maxResults = 50
    ).execute()

videos = []
channels = []
playlists = []

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'EW434bfpvWXZbJz-0v-n8zNpHnQ',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'wGkiSJC2-BlcX6x_NtiO4LfrFNk',
#    'id': {'kind': 'youtube#video', 'videoId': '_XiDloDKpro'},
#    'snippet': {'publishedAt': '2020-05-09T17:38:51Z',
#     'channelId': 'UCN3S-GAmJTcdAh7LZjg3jHQ',
#     'title': 'Call Of Duty Modern Warfare 1 v 1 Face off! Ft. Lolzzz Gaming',
#     'description': 'Support the stream: https://streamlabs.com/prasadjoshi ROG Strix 2080 Overclocked Edition 8GB Buy Now Link: https://www.primeabgb.com/online-pric.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_XiDloDKpro/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_XiDloDKpro/mqdefault_live.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_XiDloDKpro/hqdefault_live.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'HYDRA BTS',
#     'liveBroadcastContent': 'live',
#     'publishTime': '2020-05-09T17:38:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xz3OOPjlR9neRp0r573AKOMN-F8',
#    'id': {'kind': 'youtube#video', 'videoId': 'XydmhwAj4B4'},
#    'snippet': {'publishedAt': '2020-05-09T16:15:30Z',
#     'channelId': 'UCJYQeQ6H0ebGBV6O7Q_HrtQ',
#     'title': 'ARMY Tweets/BTS Memes cuz we are getting MOTS 7 : THE JOURNEY',
#     'description': 'Get Kpop your Apparel at - http://bit.ly/taeggukieKpopMerch Get Funny Apparel – Girl Side http://bit.ly/taeggukieGirlFunnyApparel Extra 5% off on Order Over $49 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XydmhwAj4B4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XydmhwAj4B4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XydmhwAj4B4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'taeggukie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T16:15:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7Evm0OQHjOY97Ps33PnY4_bzWwY',
#    'id': {'kind': 'youtube#video', 'videoId': 'kmlvWipgGKQ'},
#    'snippet': {'publishedAt': '2020-05-09T15:00:32Z',
#     'channelId': 'UCIsxqATKanisRxmyctH4Qog',
#     'title': 'До слёз смешные видео с BTS из Instagram БТС Инстаграм #1234',
#     'description': 'Мой 2й канал: https://www.youtube.com/channel/UCfxd3c0PUitC7_mkWTLweWQ ⚪⚪⚪⚪⚪ Реклама на канале - https://clck.ru/Hn3aE Почта (по вопросам ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kmlvWipgGKQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kmlvWipgGKQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kmlvWipgGKQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JJ News — Факты и новости о BTS, всё про k-pop',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T15:00:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Lu5AIInTTijpydrV4O_ww5BCp9I',
#    'id': {'kind': 'youtube#video', 'videoId': 'iinaCf8RM-Y'},
#    'snippet': {'publishedAt': '2020-05-09T15:00:29Z',
#     'channelId': 'UC3qGy9-gqF-jKBstqv5WCWw',
#     'title': 'GOODBYE HATERS! (BTS (방탄소년단) &#39;Cypher Pt.4&#39; | Song Reaction/Review)',
#     'description': 'My reaction & review of the rapline of BTS\' fourth Cypher, "Cypher Pt.4". Join My Discord: https://discord.gg/pWxjXkj Instagram: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iinaCf8RM-Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iinaCf8RM-Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iinaCf8RM-Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MrSammyCam',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T15:00:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zppIIin6Fn22NSBYpP33r9pf0IA',
#    'id': {'kind': 'youtube#video', 'videoId': 'yAYOE-qz3qo'},
#    'snippet': {'publishedAt': '2020-05-09T14:00:31Z',
#     'channelId': 'UCynydpoUPYHbpednftXDrTQ',
#     'title': 'Why BTS Is So Successful',
#     'description': 'The Power & Success Of BTS As of 2020, #BTS is the biggest #Kpop group on the planet. With 7 charming and talented members, the group has become the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yAYOE-qz3qo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yAYOE-qz3qo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yAYOE-qz3qo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'GossipBoy',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T14:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2egwvb1zJxqhx3sGTgHaQ_ZDOS0',
#    'id': {'kind': 'youtube#video', 'videoId': 'WZxwkrp2Hqs'},
#    'snippet': {'publishedAt': '2020-05-09T08:02:14Z',
#     'channelId': 'UCzWT3oqj7KCqStMnwQS1qng',
#     'title': 'BTS 방탄소년단 그대로 따라한 탄도소년단 BTZ 놀라운 근황 드디어 그룹 해체 임박 케이팝 표절한 제이팝 결과 BTS KPOP Copycat Japanese JPOP',
#     'description': '방탄소년단을 따라한 오리지널 유명 표절 그룹 탄도소년단의 근황이 화제입니다. 방탄을 따라해 초반에 인기를 얻었으나 현재는 그런 인기가...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WZxwkrp2Hqs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WZxwkrp2Hqs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WZxwkrp2Hqs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '팩트코리아',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T08:02:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Q8lHfrDFUu_qDQhQuccw_DShEGk',
#    'id': {'kind': 'youtube#video', 'videoId': 'RC6ct1zkhV0'},
#    'snippet': {'publishedAt': '2020-05-09T03:58:46Z',
#     'channelId': 'UCZPm1nwXI23r14Fu-n9WD3Q',
#     'title': '（bts妄想）&quot;夜のプールで🔞&quot; テヒョン🐯',
#     'description': 'みなさんこんにちは! やっぱりまだ物語編は出さないでおきます。 本当に身勝手でごめんなさい    \u200d♀️ 今回は、テヒョン妄想です! 苦...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RC6ct1zkhV0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RC6ct1zkhV0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RC6ct1zkhV0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ましゅまろ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T03:58:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kYelaHH8UXr7r7yrY2NCbTCcJwQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'ddmxNRhRvhM'},
#    'snippet': {'publishedAt': '2020-05-09T03:41:17Z',
#     'channelId': 'UCfcpx5VaGcx23nE8eTSljTA',
#     'title': 'Tiktok BTS ARMY edit _ muốn xem thì giữ cho chặt cái liêm sỉ',
#     'description': 'BTS#ARMY#BEE_NEK.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ddmxNRhRvhM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ddmxNRhRvhM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ddmxNRhRvhM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Bee Nek',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T03:41:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N87oOabiFYATS0183aUnfmolB6E',
#    'id': {'kind': 'youtube#video', 'videoId': '5Z0UkIZ697g'},
#    'snippet': {'publishedAt': '2020-05-09T03:31:16Z',
#     'channelId': 'UCQPn5uTbTPczQ_f1ljwVDuA',
#     'title': 'BTS V Taehyung Cried After An Argument With Jin | BTS Burn The Stage',
#     'description': 'BTS V Taehyung Cried After An Argument With Jin | BTS Burn The Stage Thanks For Watching ❤️ Please give this video a like, share and please SUBSCRIBE!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5Z0UkIZ697g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5Z0UkIZ697g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5Z0UkIZ697g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'love K&R',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T03:31:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FMhcg8UX8EO3g2WIwXfqUvOdh9U',
#    'id': {'kind': 'youtube#video', 'videoId': 'jPKG1jf97BQ'},
#    'snippet': {'publishedAt': '2020-05-09T03:11:55Z',
#     'channelId': 'UC093kTJdVRhwP30sMZYnoqg',
#     'title': 'BTS (방탄소년단) &#39;DNA&#39; Official MV REACTION',
#     'description': "MORE BTS REACTIONS on Patreon: https://www.patreon.com/dtparker Bon Voyage Run BTS Burn the Stage Live Performances 'DNA' is about the hit the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jPKG1jf97BQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jPKG1jf97BQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jPKG1jf97BQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'DT Parker',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T03:11:55Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vef5QoR1usPaJ079nI6cHdN3R4Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'Js_-z7xClkg'},
#    'snippet': {'publishedAt': '2020-05-09T02:51:24Z',
#     'channelId': 'UCOXpMUtGePdBpiUWcrY5Tjg',
#     'title': '[ASMR BTS] - Vc é a intercambista na escola deles',
#     'description': 'Sinopse Vc ganha uma bolsa de estudos para estudar na coreia do sul onde os meninos estudam Passando um tempo vc conhece Jungkook o lider e popular ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Js_-z7xClkg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Js_-z7xClkg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Js_-z7xClkg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ASMR BTS IMAGINES',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T02:51:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'g8tSgZGnISVKH_f9_yFZDXGXagc',
#    'id': {'kind': 'youtube#video', 'videoId': '3itlGrYkDl4'},
#    'snippet': {'publishedAt': '2020-05-09T00:50:01Z',
#     'channelId': 'UCwuwE3q0A1I8uy4pbQhq8xg',
#     'title': 'DANCE TIED WITH LIE!? | BTS &#39;Boy Meets Evil&#39; Comeback Trailer + Explained | Reaction',
#     'description': "Support the channel by becoming a Patreon https://www.patreon.com/xHeyCharliex DANCE TIED WITH LIE!? | BTS 'Boy Meets Evil' Comeback Trailer + ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3itlGrYkDl4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3itlGrYkDl4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3itlGrYkDl4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hey Charlie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-09T00:50:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PVVOG9t3Z8e2qU2IVoT81jhqM00',
#    'id': {'kind': 'youtube#video', 'videoId': 'fEcTBGBodPc'},
#    'snippet': {'publishedAt': '2020-05-08T22:54:40Z',
#     'channelId': 'UC2GF1LsqB3BrSoigfmhXVXg',
#     'title': 'BTS - BTS IN QUARANTINE *Reaction*',
#     'description': 'LIVE STREAM CHANNEL: https://www.youtube.com/channel/UCLnHFIBI-Lc_i8ilaccz1qQ TAP   http://www.patreon.com/kingblitzmusic TAP   ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fEcTBGBodPc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fEcTBGBodPc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fEcTBGBodPc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'KING BLITZ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T22:54:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iTesCMRV_bDdRKDnLWlwnpO-beU',
#    'id': {'kind': 'youtube#video', 'videoId': 'u4soFaRCv_0'},
#    'snippet': {'publishedAt': '2020-05-08T20:57:22Z',
#     'channelId': 'UC0qswm_imv_325BqQd1SPFA',
#     'title': 'J-HOPE KILLED THIS! 😮BTS (NO MORE DREAM) DANCE PRACTICE &amp; LIVE | REACTION',
#     'description': 'THEY KEEP KILLING ME WITH THEIR DANCE BREAKS!!! Intro soundtrack: TOURI$T - Look 4 Me @callmetour https://soundcloud.com/user-717295640.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u4soFaRCv_0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u4soFaRCv_0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u4soFaRCv_0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'CHIU views',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T20:57:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'j3C1UWBv02KWdECQPjyIVAM4bGU',
#    'id': {'kind': 'youtube#video', 'videoId': 'VR1vGbTXSsY'},
#    'snippet': {'publishedAt': '2020-05-08T20:52:27Z',
#     'channelId': 'UCRGdrMoq9nateD0Wciv5ceA',
#     'title': 'BTS &#39;IDOL FEAT. NICKI MINAJ&#39; OFFICIAL MUSIC VIDEO FIRST TIME REACTION VIDEO | MISS LYLY',
#     'description': "We're both fans of Nicki Minaj but don't think she added anything extra to this song or video, would have preferred if she was actually in the same scenes as the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VR1vGbTXSsY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VR1vGbTXSsY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VR1vGbTXSsY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Miss Lyly & Co',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T20:52:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OlIs5he2MeB7UE2XZD39EI5IYIA',
#    'id': {'kind': 'youtube#video', 'videoId': 'GDFXOeBxwUs'},
#    'snippet': {'publishedAt': '2020-05-08T20:49:42Z',
#     'channelId': 'UCHG24BAh3-5uo_BEp8wcIrw',
#     'title': 'BTS REACTION TIKTOK INDO | CEWEK CANTIK YANG LAGI VIRAL',
#     'description': 'BTSREACTION.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GDFXOeBxwUs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GDFXOeBxwUs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GDFXOeBxwUs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Eko Supriyadii',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T20:49:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GbUhHnXTs3jdcz2yGTcGltGenHo',
#    'id': {'kind': 'youtube#video', 'videoId': 'AbHHYsWyi7Y'},
#    'snippet': {'publishedAt': '2020-05-08T20:38:25Z',
#     'channelId': 'UCPAz3hWHiBC-c1x4K0-atsg',
#     'title': 'K-BALLADS FOR THE FIRST TIME PT2| BTS,MAMAMOO,BIGBANG,EXO,BLACKPINK,JONGHYUN,AKMU,PARK HYO SHIN,DAY6',
#     'description': "Welcome to this week's FEATURE FRIDAY ✌ This week we talk about ULTIMATE POWER BALLADS PART2 by some amazing South Korean singers like BTS ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AbHHYsWyi7Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AbHHYsWyi7Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AbHHYsWyi7Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Waleska Herrera',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T20:38:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6mfG-BIeP2Gcgj1022N8kfqPpug',
#    'id': {'kind': 'youtube#video', 'videoId': 'HEXaAqRxTrw'},
#    'snippet': {'publishedAt': '2020-05-08T20:29:16Z',
#     'channelId': 'UCgnfPl5tZJlWQbnHPA_QQng',
#     'title': '[LIGAÇÃO] BTS - JIKOOK EM : A POÇÃO DO AMOR | KPOBREA',
#     'description': '⃟·やあᎷᎬႮ ᎪᎷᏆΝϴ : http://aminoapps.com/p/6cldjb 🥞⃟·やあCOMUNIDADE DO AMINO: http://aminoapps.com/invite/QCZWRJRQWW 🥞⃟·やあᎷᎬႮ ᏆΝՏͲ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HEXaAqRxTrw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HEXaAqRxTrw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HEXaAqRxTrw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'KPOBREA',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T20:29:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OGOD8YxjtF_YlAFOfTlOADWSb3Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'Iy5UtwutXec'},
#    'snippet': {'publishedAt': '2020-05-08T19:03:46Z',
#     'channelId': 'UCUq2FnQA212jYzOZe30wXWg',
#     'title': 'Teve beijo na live do BTS???; Novo grupo de garotos da BH; E+',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Iy5UtwutXec/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Iy5UtwutXec/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Iy5UtwutXec/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BTS NEWS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T19:03:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QHOFVvA54SjxFj8Mg3OBcKInrH0',
#    'id': {'kind': 'youtube#video', 'videoId': 'zHNWZv1Fjlg'},
#    'snippet': {'publishedAt': '2020-05-08T17:37:19Z',
#     'channelId': 'UCSzEumgU3XabWOAFej-GA9w',
#     'title': 'ATENCION! V DE BTS DEBUTARÁ COMO SOLISTA!| JIMIN Y LISA!💜| ELLOS SE VAN AL SERVICIO MILITAR!| Y MÁS',
#     'description': 'COMPRA en Beautifulhalo : http://bit.ly/ZonaK-popMerch POR FAVOR SIGUENOS EN INSTAGRAM! https://www.instagram.com/zona_kpoptv/ Aca ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zHNWZv1Fjlg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zHNWZv1Fjlg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zHNWZv1Fjlg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ZONA K-POP',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T17:37:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'mggZjIF68TOlMZU-WrSa11pytjY',
#    'id': {'kind': 'youtube#video', 'videoId': 'xvgFUrnysns'},
#    'snippet': {'publishedAt': '2020-05-08T17:30:10Z',
#     'channelId': 'UC5MJlz1kOV0ZCYde11Dxc_g',
#     'title': 'BTS being chaotic as always in America pt.2',
#     'description': 'Have fun! ♥ Our second channel: https://www.youtube.com/channel/UCwg_rBQ2d_ftOCpQvFL7zKw ⚡ Twitter- https://twitter.com/BornToSlay_gurl?lang=en ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xvgFUrnysns/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xvgFUrnysns/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xvgFUrnysns/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BornToSlay',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T17:30:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'msgWYctB0JTx6g3trKOat9Tk5uM',
#    'id': {'kind': 'youtube#video', 'videoId': 'j_tHQlA2Ens'},
#    'snippet': {'publishedAt': '2020-05-08T15:13:24Z',
#     'channelId': 'UC0Pm-yFJGhlJyLgq0EziBkw',
#     'title': '【日本語字幕】꿀FMことシュガFMで朗読会！BTSメンバーが総出演...！？(BTS/防弾少年団)',
#     'description': '꿀FMことシュガFMに日本語字幕と絵をつけてみました！ びっくりするほど画像選びと切り抜きが疲れましたが...頑張った....！ ラストのYEAHのスペ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j_tHQlA2Ens/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j_tHQlA2Ens/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j_tHQlA2Ens/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'キヨ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T15:13:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-iDpbYfPTB1A0BMcGzf0_-TYWxU',
#    'id': {'kind': 'youtube#video', 'videoId': '4lXNt3-CoDs'},
#    'snippet': {'publishedAt': '2020-05-08T14:21:32Z',
#     'channelId': 'UCVejSs7s9X7rKjOz7q4Cjug',
#     'title': 'Army tweets/bts memes that LITERALLY HAVE ME ON THE FLOOR LAUGHING',
#     'description': 'Some more army tweets/bts memes that got me wheezing of laughter Instagram: https://www.instagram.com/fanboyhayden/ Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4lXNt3-CoDs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4lXNt3-CoDs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4lXNt3-CoDs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Hayden Brock',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T14:21:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OIxBSx90PKwVd-Ugz35kBEFNbBg',
#    'id': {'kind': 'youtube#video', 'videoId': 'Kx7-nKQbwK4'},
#    'snippet': {'publishedAt': '2020-05-08T13:35:36Z',
#     'channelId': 'UCQ1kJRiiaA_ezpDuVth0PwQ',
#     'title': 'pls send help ✰ BTS + Drugs = This Video ✰ BTS REACTION',
#     'description': 'This is my reaction to BTS + Drugs = This Video... oh dear. please never actually give them anything. Subscribe! LINKS TAKING BTS BUZZFEED ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kx7-nKQbwK4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Kx7-nKQbwK4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Kx7-nKQbwK4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'caitlin marie reacts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T13:35:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P-sFbWoxmborAJX-n6M2Ey1EXI4',
#    'id': {'kind': 'youtube#video', 'videoId': '_SsXcSNO1gQ'},
#    'snippet': {'publishedAt': '2020-05-08T13:05:18Z',
#     'channelId': 'UCJrOtniJ0-NWz37R30urifQ',
#     'title': 'THE WAY OUT - Ep. 4 - Alone, Pt. II BTS',
#     'description': 'The last episode in the Alone, Pt.II Behind The Scenes series! I am so happy that everyone came home okay after shooting in the jungle and in the cave, even ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_SsXcSNO1gQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_SsXcSNO1gQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_SsXcSNO1gQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alan Walker',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T13:05:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7N_T3uVz4IEL946TY675_sBS6w4',
#    'id': {'kind': 'youtube#video', 'videoId': 'u7eJmKyPOH0'},
#    'snippet': {'publishedAt': '2020-05-08T13:03:37Z',
#     'channelId': 'UCJrOtniJ0-NWz37R30urifQ',
#     'title': 'ARRIVING IN VIETNAM - Ep. 2 - Alone, Pt. II BTS',
#     'description': 'In episode 2 the crew have arrived Vietnam and are going into the jungle and enter the Han Son Doong cave. None of the Norwegians had ever been in a cave ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u7eJmKyPOH0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u7eJmKyPOH0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u7eJmKyPOH0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alan Walker',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T13:03:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'B00CVI92mPZe2VrGgiqHhJdroaA',
#    'id': {'kind': 'youtube#video', 'videoId': 'PjF8CVQQavA'},
#    'snippet': {'publishedAt': '2020-05-08T13:00:13Z',
#     'channelId': 'UC3qGy9-gqF-jKBstqv5WCWw',
#     'title': 'THEY&#39;RE ALL CRAZY! (BTS + Drugs = This Video | Reaction/Review)',
#     'description': 'My reaction & review of BTS + Drugs = This Video.. Join My Discord: https://discord.gg/pWxjXkj Instagram: https://www.instagram.com/mrsammycam ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PjF8CVQQavA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PjF8CVQQavA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PjF8CVQQavA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MrSammyCam',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T13:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'w_JZFUZrc_-YpXzMU2oJfd7pkbs',
#    'id': {'kind': 'youtube#video', 'videoId': 'XPapp31VNxQ'},
#    'snippet': {'publishedAt': '2020-05-08T12:45:35Z',
#     'channelId': 'UC1KonH1j8WMhc5cT6Bp7NtA',
#     'title': 'Episode 3 | Gur Nalo Ishq Mitha | BTS | Season 1 | Yo Yo Honey Singh',
#     'description': "Episode 3: India's first Bhangra Hip Hop song Gur Nalo Ishq Mitha - The YOYO Remake is sung and composed by Yo Yo Honey Singh, featuring “ Malkit Singh ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XPapp31VNxQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XPapp31VNxQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XPapp31VNxQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yo Yo Honey Singh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T12:45:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Y_UQM6RS7ePrHeg7RFit-13Z63Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'rp-2mxiAqJc'},
#    'snippet': {'publishedAt': '2020-05-08T12:07:32Z',
#     'channelId': 'UCVf-feCOc-Inr3QPJkUL6uA',
#     'title': 'BTS’s real thoughts about each other',
#     'description': 'Here is what BTS thought about each other back in 2014 “he is a genius but also dumb” “anything he says is a lie” or “he is not someone you can hate” Who is ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rp-2mxiAqJc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rp-2mxiAqJc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rp-2mxiAqJc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'MisuPlus',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T12:07:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bOJSZueRV2NA3UuQI08reLC8tUQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'eJlX37t-G0o'},
#    'snippet': {'publishedAt': '2020-05-08T11:31:48Z',
#     'channelId': 'UCZhskpD2GI_O-mmEcKyhU8A',
#     'title': '[BTS funny moments 48] BTS và các thể loại Tiktok (Phần 3)',
#     'description': 'Ghé blog instagram mình nhé 🤗 https://www.instagram.com/btstun99/ Vui lòng không reup trên YOUTUBE và Facebook #BTS #BTSTUN999 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eJlX37t-G0o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eJlX37t-G0o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eJlX37t-G0o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BTS TỦN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T11:31:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OwB1xSxnQJGRn5aCLfAtCCw4Egs',
#    'id': {'kind': 'youtube#video', 'videoId': '3ZGHnpZ2Dbw'},
#    'snippet': {'publishedAt': '2020-05-08T11:02:37Z',
#     'channelId': 'UCHzbmiu_C2bEhJcHOhVn3kg',
#     'title': '2 Minute KPOP Dance Challenge (BTS, EXO, Twice, NCT 127, Itzy, MonstaX, and more!)',
#     'description': "ACBonifacio #KPop #DanceChallenge CAPTION: Hey guys! Here's another dance challenge that I did. I only had TWO MINUTES to learn key parts of specific ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3ZGHnpZ2Dbw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3ZGHnpZ2Dbw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3ZGHnpZ2Dbw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Andree Bonifacio',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T11:02:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0_8689gssS7_-Zz4NSV48cc8AdI',
#    'id': {'kind': 'youtube#video', 'videoId': 'eV0RTrP9pjM'},
#    'snippet': {'publishedAt': '2020-05-08T10:57:07Z',
#     'channelId': 'UCaZhnsQ36GIYYQ1sbxKeMDg',
#     'title': '아이유(IU) - 에잇(Eight) (Prod.&amp; Feat. SUGA Of BTS) / 가사',
#     'description': '아이유(IU) - 에잇(Eight) (Prod.& Feat. SUGA Of BTS) - credit - Lyrics by 아이유, SUGA Composed by SUGA, 아이유, EL CAPITXN Arranged by SUGA, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eV0RTrP9pjM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eV0RTrP9pjM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eV0RTrP9pjM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Music is my life',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T10:57:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'A6rPInyqOt_rw7c3L_lkx_IRm2E',
#    'id': {'kind': 'youtube#video', 'videoId': 'xWgv6-tZSvg'},
#    'snippet': {'publishedAt': '2020-05-08T10:00:39Z',
#     'channelId': 'UCfsCwuRVG1orBa9cjgZSxfQ',
#     'title': '[REACTION] EIGHT - IU Feat. SUGA BTS จุกครับ',
#     'description': 'Zellfie #IUeight #SUGA.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xWgv6-tZSvg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xWgv6-tZSvg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xWgv6-tZSvg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Zellfie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T10:00:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4xH8lgNZbCOybPKgyvtluBAozTY',
#    'id': {'kind': 'youtube#video', 'videoId': 'XlVCdN-jbMQ'},
#    'snippet': {'publishedAt': '2020-05-08T10:00:12Z',
#     'channelId': 'UCXdRvUovEANz8EZEe67e8Sg',
#     'title': 'BTS、Red Velvet 也抵擋不了的TWICE魅力！盤點10組IDOL們看到TWICE的超真反應－Blackpink／Gfriend／MAMAMOO／ITZY／EXO／GOT7｜TEEPR推一波',
#     'description': 'TWICE #Redvelvet #BTS 大家聽到TWICE什麼歌會受不了跟著跳起來？（像我就是聽到Fancy會整個受不了） 不過相信不只粉絲會忍不住愛豆們聽到應該也會忍...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XlVCdN-jbMQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XlVCdN-jbMQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XlVCdN-jbMQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'TEEPR 推一波',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T10:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fLWEjryThnN8kgNyZb-gW2rByoA',
#    'id': {'kind': 'youtube#video', 'videoId': 'b0zf8S34DrI'},
#    'snippet': {'publishedAt': '2020-05-08T10:00:24Z',
#     'channelId': 'UC3SyT4_WLHzN7JmHQwKQZww',
#     'title': '[IU TV] 옥상으로 따라와! &#39;에잇&#39;(Prod.&amp;Feat. SUGA of BTS) M/V 비하인드',
#     'description': "IUTV #IU #dlwlrma [IU TV] Come up to rooftop! 'eight'(Prod.&Feat. SUGA of BTS) M/V Behind [IU TV] 옥상으로 따라와! '에잇'(Prod.&Feat. SUGA of BTS) M/V ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/b0zf8S34DrI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/b0zf8S34DrI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/b0zf8S34DrI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '이지금 [IU Official]',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T10:00:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'z8KdTVt2Ofj_ir2GHYWfrabYzJM',
#    'id': {'kind': 'youtube#video', 'videoId': '-Zq0AfaEz0Y'},
#    'snippet': {'publishedAt': '2020-05-08T10:00:13Z',
#     'channelId': 'UCQiVlNkbKbnM204zY6hnE2g',
#     'title': 'BTS Flirting With Fans',
#     'description': "BTS Flirting With Fans Copyright disclaimer: I do NOT own this video. All rights belong to it's rightful owner/owner's. No copyright infringement intended.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-Zq0AfaEz0Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-Zq0AfaEz0Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-Zq0AfaEz0Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BTS stan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T10:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yu0xB1he_9CWqg4ren2PPro08oQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'DTgZQT5rwzs'},
#    'snippet': {'publishedAt': '2020-05-08T09:06:43Z',
#     'channelId': 'UCHa5dDtdde3WSQvjoiHdZ0g',
#     'title': 'Nữ ca sĩ Suran khiến fan BTS tức điên vì hành động được cho là thả thính Suga trên story Instagram',
#     'description': 'Hashtags:#TopSaoHan #tinsaohan #BTSSuga ▻ Đăng ký kênh để cập nhật những video mới nhất (Tại đây) ▻ https://bitlylink.com/XfyoL Top Sao Hàn tổng ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DTgZQT5rwzs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DTgZQT5rwzs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DTgZQT5rwzs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Top Sao Hàn',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T09:06:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pdj8_Tq8AMsm9jNLbB9WDK7potc',
#    'id': {'kind': 'youtube#video', 'videoId': 'K9B39XouW2A'},
#    'snippet': {'publishedAt': '2020-05-08T08:53:30Z',
#     'channelId': 'UCv0FT71ly3cBD9OuN9v5U8A',
#     'title': 'Best of BTS JIKOOK 2 (Jimin &amp; Jungkook)',
#     'description': 'Part 1: https://www.youtube.com/watch?v=JA1r-vdEIAE Another fun video of these boys. Be silly and do your passion. Stay safe everyone. All videos are not ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/K9B39XouW2A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/K9B39XouW2A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/K9B39XouW2A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Best of BTS',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T08:53:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'q43F98h772Kibx619PiJG5lLUM0',
#    'id': {'kind': 'youtube#video', 'videoId': 'gLlgpEN3p7M'},
#    'snippet': {'publishedAt': '2020-05-08T08:19:33Z',
#     'channelId': 'UCAbu-rUyFqWw5k5jlSG-Jvw',
#     'title': '[VLIVE] BTS - 🕺진기민 충격적인 깜찍함에 내 심장 저스트 가루박살 나우💃 (BTS playing dance game)',
#     'description': "[FULL] BTS - 진기민   ↘️ https://www.vlive.tv/video/188036 ☆ Enjoy K-POP celeb's LIVE broadcast with English subtitle on VLIVE! \u200b\u200b더 많은 셀럽의 영상을 ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gLlgpEN3p7M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gLlgpEN3p7M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gLlgpEN3p7M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'V LIVE',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T08:19:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9XzOkRmiZakJWGS392m0qhHVyN0',
#    'id': {'kind': 'youtube#video', 'videoId': 'p1TlsqrJxm8'},
#    'snippet': {'publishedAt': '2020-05-08T06:20:38Z',
#     'channelId': 'UCdb5uFnBrM18ni4rRVNIPuA',
#     'title': 'BTS Memes That Left Me Shook',
#     'description': 'Hi loves I hope you enjoy the video! time to relax with some bangtan sonyeondan uwu follow me on twitter: @bunnyjungx I see a lot, A LOT of people asking me ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/p1TlsqrJxm8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/p1TlsqrJxm8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/p1TlsqrJxm8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'International Army',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T06:20:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fLbdIlecC-Y4dhGy8J0UsJro9wM',
#    'id': {'kind': 'youtube#video', 'videoId': 'ywfNH4nvzUg'},
#    'snippet': {'publishedAt': '2020-05-08T05:56:03Z',
#     'channelId': 'UCzWT3oqj7KCqStMnwQS1qng',
#     'title': 'BTS 방탄소년단 때문에 대박나버린 한국 제품 없어서 못 판다는 현재 상황에 환호하는 한국회사 BTS 2020 Bodyfriend TVCF Lives Healthy',
#     'description': '방탄소년단 때문에 제품이 역대급 판매량을 기록한 한국회사가 화제입니다. 방탄소년단의 광고 모델 마켓팅 효과는 대단합니다. 기존의 예측...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ywfNH4nvzUg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ywfNH4nvzUg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ywfNH4nvzUg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '팩트코리아',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T05:56:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bsxpNtfb5KPyf4bSqbr-6OWh05Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'Xdm8VX25MfM'},
#    'snippet': {'publishedAt': '2020-05-08T03:00:12Z',
#     'channelId': 'UCTlzx8PsEtsgl3qGC0bMWLw',
#     'title': 'When Celebrities Meet BTS',
#     'description': "When Celebrities Meet BTS Copyright disclaimer: I do NOT own this video. All rights belong to it's rightful owner/owner's. No copyright infringement intended.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xdm8VX25MfM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Xdm8VX25MfM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Xdm8VX25MfM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kpop VGK',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T03:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LklUFoAJPhzYfckqLHhIrZ2qLZw',
#    'id': {'kind': 'youtube#video', 'videoId': '6NQ5vxMf8N4'},
#    'snippet': {'publishedAt': '2020-05-08T02:03:03Z',
#     'channelId': 'UCQ99CmIeeIL6CNR6vHAf9Wg',
#     'title': 'REACTING TO BTS&#39; MOST UNDERRATED SONG!',
#     'description': 'More videos on our Patreon: https://www.patreon.com/fosquadkpop MORE K-POP REACTIONS HERE: https://www.youtube.com/kpopuniversity REACTING TO ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6NQ5vxMf8N4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6NQ5vxMf8N4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6NQ5vxMf8N4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'FO Squad Kpop',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T02:03:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'brwANQhrQ8DQfeeSKLtVuKla_2Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'xiYv4M9Y36o'},
#    'snippet': {'publishedAt': '2020-05-08T01:02:53Z',
#     'channelId': 'UCQPn5uTbTPczQ_f1ljwVDuA',
#     'title': 'BTS PARK JIMIN&#39;S HABITS!',
#     'description': "BTS PARK JIMIN'S HABITS! Thanks For Watching ❤️ Please give this video a like, share and please SUBSCRIBE! Keep Hitting That Subscribe Button For Us ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xiYv4M9Y36o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xiYv4M9Y36o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xiYv4M9Y36o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'love K&R',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T01:02:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '54vSH-lJEd-P5VgLaDbIFPKrPlI',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCWfrXy2Ruv2YhOSEIsYbTIQ'},
#    'snippet': {'publishedAt': '2020-05-08T00:36:11Z',
#     'channelId': 'UCWfrXy2Ruv2YhOSEIsYbTIQ',
#     'title': 'suga . bts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-8SBsdvg4lh8/AAAAAAAAAAI/AAAAAAAAAAA/FGrMqPeL2QI/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-8SBsdvg4lh8/AAAAAAAAAAI/AAAAAAAAAAA/FGrMqPeL2QI/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-8SBsdvg4lh8/AAAAAAAAAAI/AAAAAAAAAAA/FGrMqPeL2QI/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': 'suga . bts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-08T00:36:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nsoHcNltcqqE1Mqszm2k4wYq6bA',
#    'id': {'kind': 'youtube#video', 'videoId': '5C5uIHi_U6o'},
#    'snippet': {'publishedAt': '2020-05-07T22:55:00Z',
#     'channelId': 'UCyYTduRxnMfdQ7Bvf_hQAZQ',
#     'title': 'BTS めざましテレビ【日本語字幕】japanese TV 日本語',
#     'description': 'BTS #めざまし #日本語字幕 #日本語 #日本語話す #Japan #TV.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5C5uIHi_U6o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5C5uIHi_U6o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5C5uIHi_U6o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BTS Life',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-07T22:55:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Gj-86_0J6Zy7Sn63vEW5DhDKW1o',
#    'id': {'kind': 'youtube#video', 'videoId': 'A7GVYgQuyXM'},
#    'snippet': {'publishedAt': '2020-05-07T22:05:28Z',
#     'channelId': 'UCFjrDmEnxrG5TRGVO0TPHLA',
#     'title': 'Júlio César: &quot;O torcedor brasileiro idolatra muito o jogador europeu.&quot; BTS #203',
#     'description': 'Ai, ai, ai, Brasil. Mais um BTS Remoto e hoje é com ele, Julio César! Ele que fez seu nome vestindo as camisas da Inter de Milão, Flamengo e Seleção ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A7GVYgQuyXM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/A7GVYgQuyXM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/A7GVYgQuyXM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Desimpedidos',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-07T22:05:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gwSViktSxL4p53IyoMd4Uu-RIhQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'qh8CZ_95DsY'},
#    'snippet': {'publishedAt': '2020-05-07T21:12:56Z',
#     'channelId': 'UCyYTduRxnMfdQ7Bvf_hQAZQ',
#     'title': '【BTS日本語字幕】朝テレビ（はやドキ）JAPAN TV 日本語',
#     'description': '本人たちも笑いがとまらない！爆笑007ゲームhttps://youtu.be/RY5mJ-qKrFk テテがぐくみんにしっとする時（三角関係マンネライン）Tae get jealous.Vminkook...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qh8CZ_95DsY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qh8CZ_95DsY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qh8CZ_95DsY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BTS Life',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-07T21:12:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sBV6sCknbCJCcR_jh0tgYcTFQOw',
#    'id': {'kind': 'youtube#video', 'videoId': 'YF81ohKavEo'},
#    'snippet': {'publishedAt': '2020-05-07T21:02:24Z',
#     'channelId': 'UCCuFsZB3d8OrYX2ymX_WmDA',
#     'title': 'BTS memes I can&#39;t live without w/ @jiminandlemonade',
#     'description': "Check out jiminandlemonade's channel here!!: https://www.youtube.com/jiminandlemonade GET MY MERCH!!: https://teespring.com/stores/mochi-chimmy ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YF81ohKavEo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/YF81ohKavEo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/YF81ohKavEo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mochi Chimmy',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-07T21:02:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eHYkZF-6GUGiZLwCUNNdv6rFknc',
#    'id': {'kind': 'youtube#video', 'videoId': 'LjjknmXI5Mo'},
#    'snippet': {'publishedAt': '2020-05-07T20:57:29Z',
#     'channelId': 'UCJWkJWw61WCjVetdQLsFN-w',
#     'title': 'Chistes de Armys de BTS - Parodia Army BTS / KPOPER VS GENTE NORMAL',
#     'description': 'Chistes de Armys de BTS / Parodia Army BTS ▻Página Web: http://bit.ly/2qZQuUZ ▻Únete y apoya este humilde canal : https://bit.ly/2E1KGyK ▻CANAL ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LjjknmXI5Mo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LjjknmXI5Mo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LjjknmXI5Mo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'ANIMEMES',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-07T20:57:29Z'}}]}

# %%
for search_result in search_response.get("items", []) :
    if search_result["id"]["kind"] == "youtube#video" :
        videos.append("%s (%s)" % (search_result["snippet"]["title"], search_result["id"]["videoId"]))
    elif search_result["id"]["kind"] == "youtube#channel" :
        channels.append("%s (%s)" % (search_result["snippet"]["title"], search_result["id"]["channelId"]))
    elif search_result["id"]["kind"] == "youtube#playlist" :
        playlists.append("%s (%s)" % (search_result["snippet"]["title"], search_result["id"]["playlistId"]))

# %% [markdown]
# ### 2. 셀레니움 활용방법

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time 

driver = webdriver.Chrome('C:/Users/kjh96/Github/ETC/chromedriver.exe')
driver.get('https://www.youtube.com/user/JTBC10news/videos')

#여기서부터
time.sleep(5)
endk = 5
while endk:
    driver.find_element_by_tag_name('body').send_keys(Keys.END)
    time.sleep(0.3)
    endk -= 1
#여기까지

page = driver.page_source

# %%
# 제목 가져오기
from bs4 import BeautifulSoup
soup = BeautifulSoup(page,'lxml')
all_title = soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')
title = [soup.find_all('a','yt-simple-endpoint style-scope ytd-grid-video-renderer')[n].string for n in range(0,len(all_title))]
title[:3]
# Out:
# ['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#  '이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#  '[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News']

# %%
# 재생시간
all_video_time = soup.find_all('span','style-scope ytd-thumbnail-overlay-time-status-renderer')
video_time = [soup.find_all('span','style-scope ytd-thumbnail-overlay-time-status-renderer')[n].string.strip() for n in range(0,len(all_video_time))]
video_time[:3]
# Out:
# ['0:36', '0:40', '5:56']

# %%
#채널명
chennel = soup.find('yt-formatted-string','style-scope ytd-channel-name').string
print(chennel)

#구독자 수
sub_num = soup.find('yt-formatted-string','style-scope ytd-c4-tabbed-header-renderer').string
print(sub_num)

#조회수, 올린지 얼마나 되었는지(업로드 시점)
c = soup.find_all('span','style-scope ytd-grid-video-renderer')
view_num = [soup.find_all('span','style-scope ytd-grid-video-renderer')[n].string for n in range(0,len(c))]
print(view_num[:3])
# Out:
# JTBC News
# 구독자 132만명
# ['조회수 2.2천회', '5시간 전', '조회수 2.8천회']

# %%
# 현재 시간
from time import localtime, strftime
extract_date = strftime("%Y/%m/%d %H:%M:%S", localtime())
extract_date
# Out:
# '2020/05/10 16:52:08'

# %%
youtube_video_list = []

x = 0 #조회수의 index
y = 1 #업로드 시점의 index

for i in range(0,len(all_title)):
    roww = []
    roww.append(title[i])
    roww.append(video_time[i].strip())
    roww.append(chennel)
    roww.append(sub_num)
    roww.append(view_num[x])
    x += 2 #조회수만 append
    roww.append(view_num[y])
    y += 2 #업로드 시점만 append
    roww.append(extract_date)
    youtube_video_list.append(roww) #2차원 list로 만들어줌
    
    youtube_video_list
# Out:
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['민주당 "전국민 고용보험 단계적 접근 필요" 속도 조절 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 574회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['민주당 "전국민 고용보험 단계적 접근 필요" 속도 조절 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 574회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"재난지원금, 우리 카드사로" 유치경쟁 과열…정부 \'제동\' / JTBC 뉴스룸',
#   '1:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['민주당 "전국민 고용보험 단계적 접근 필요" 속도 조절 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 574회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"재난지원금, 우리 카드사로" 유치경쟁 과열…정부 \'제동\' / JTBC 뉴스룸',
#   '1:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['트럼프 수행비서 이어 펜스·이방카 측근도 확진…백악관 비상 / JTBC 뉴스룸',
#   '3:14',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['민주당 "전국민 고용보험 단계적 접근 필요" 속도 조절 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 574회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"재난지원금, 우리 카드사로" 유치경쟁 과열…정부 \'제동\' / JTBC 뉴스룸',
#   '1:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['트럼프 수행비서 이어 펜스·이방카 측근도 확진…백악관 비상 / JTBC 뉴스룸',
#   '3:14',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['13일 등교 개학은?…정부 "연기 거론 시기상조, 상황 주시" / JTBC 뉴스룸',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 733회',
#   '20시간 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
# ...
#  ['이태원 클럽, 4~5일에 또 다른 확진자…접촉자 추적 어떻게? / JTBC 뉴스룸',
#   '4:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["직장 동료도 확진, 건물 통째 폐쇄…'클럽발' 일파만파 / JTBC 뉴스룸",
#   '1:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['부산 클럽 확진자 땐 추가감염 없었는데…뭐가 달랐나 / JTBC 뉴스룸',
#   '1:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'이태원 클럽' 방문자만 1500명 넘어…집단감염 '새 뇌관' / JTBC 뉴스룸",
#   '2:22',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["2020년 5월 8일 (금) 정치부회의 다시보기 - '용인 확진자' 관련 감염자 속출…방역 비상",
#   '1:10:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7.8천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["대전 현충원 '전두환 현판' 철거…역사 바로세우기 / JTBC 정치부회의",
#   '3:29',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['김태년 "일하는 국회 만들 것…법사위, 제 위치로" / JTBC 정치부회의',
#   '7:25',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['미래통합당 신임 원내대표 주호영 선출 / JTBC 정치부회의',
#   '5:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 612회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'용인 확진자' 관련 감염자 속출…방역 비상 / JTBC 정치부회의",
#   '3:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[답하겠쏘라] 직장 내 성추행 왜 일어날까?｜JTBC 소셜라이브 Q&A 25탄',
#   '5:26',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 893회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전] 김정은, 시진핑에 "방역 성공 축하"…해석은? (2020.05.08 / JTBC 뉴스ON)',
#   '4:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전] 트럼프, 또 방위비 압박?…일방적 '땡큐 코리아' (2020.05.08 / JTBC 뉴스ON)",
#   '5:41',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.5천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전] 위성정당의 '딴마음'?…국민의당과 연합설 '솔솔' (2020.05.08 / JTBC 뉴스ON)",
#   '8:14',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전] 새 원내사령탑에 김태년-주호영…21대 국회 전망은? (2020.05.08 / JTBC 뉴스ON)',
#   '22:08',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전 H/L] 취임 3주년 앞둔 문 대통령…지지율 '고공행진' / JTBC 뉴스ON",
#   '2:10',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.6만회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전 H/L] 김종배 "이낙연 발언, 오히려 \'겸손\'으로 해석할 수도" / JTBC 뉴스ON',
#   '4:37',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.9천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전 H/L] '슈퍼 여당' 원내대표 김태년…당청 관계 전망은? / JTBC 뉴스ON",
#   '7:23',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 253회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전 H/L] 통합당 새 원내대표 주호영…김종배 "마구잡이 투쟁 없을 것" / JTBC 뉴스ON',
#   '5:07',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 818회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 황운하 "공수처 취지는 검찰개혁…그래서 윤석열이 1호 수사대상 거론" / JTBC 뉴스ON',
#   '14:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 10만회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["법원, 정경심 '구속 연장' 불가 결정…11일 0시 석방  / JTBC 뉴스ON",
#   '1:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 3.4천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['첫 재판 나온 조국 "검찰 왜곡 하나하나 반박…지치지 않고 싸울 것"  / JTBC 뉴스ON',
#   '1:50',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 930회',
#   '2일 전',
#   '2020/05/10 16:52:08']]
# [['제주서 이태원 방문 코로나19 확진자 발생 / JTBC News',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽 방문자 7222명 전수조사 / JTBC News',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.8천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC News',
#   '5:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 517회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상',
#   '47:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9만회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"',
#   '3:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ['[취임 3주년 연설] 문 대통령 "임기 마지막까지 위대한 국민 함께 담대하게 나아갈 것" / JTBC News',
#   '22:30',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '5시간 전',
#   '2020/05/10 16:52:08'],
#  ["[이슈정주행] 기술진 모셔가고, 마스크·키트 수출 고공행진…K방역의 '위상' / JTBC News",
#   '9:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7천회',
#   '7시간 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "세월호, 손해배상 관점으로 교통사고…소신에 변함 없다" / JTBC 정치부회의',
#   '2:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8천회',
#   '8시간 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] '이태원발' 집단 감염...지역사회 확산 우려 / JTBC News",
#   '14:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2만회',
#   '19시간 전',
#   '2020/05/10 16:52:08'],
#  ['숨진 한국인 교사, 네팔서 장례…하늘길 열리면 봉환 / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.6천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['전남 해남서 규모 2.2 지진…최근 2주간 74번 / JTBC 뉴스룸',
#   '0:34',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['휘발유 리터당 1257.6원…15주 연속 하락세 / JTBC 뉴스룸',
#   '0:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 713회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['정의연 측 "내주에도 수요시위…월요일에 기자회견" / JTBC 뉴스룸',
#   '0:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 박원순 "4시간 새 확진자 7명 늘어…전방위 조치로 확산 막을 것" (2020.05.09 / JTBC 뉴스룸)',
#   '5:03',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.7천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['5월 9일 (토) 뉴스룸 엔딩곡 (BGM : Find - 솔비) / JTBC News',
#   '0:32',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 652회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['세계가 주목한 K리그…개막 축포 이동국엔 "한국축구 전설" / JTBC 뉴스룸',
#   '1:55',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['[오픈마이크] 어린이날 딸 손 대신 전단지 쥐고 어린이대공원에…"자식을 찾고 있어요" / JTBC 뉴스룸',
#   '4:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['조깅하던 흑인 청년, 백인 총에 숨져…"인종차별" 미 발칵 / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'누출 사고' LG화학에 81억 공탁명령…현지 줄소송 예고 / JTBC 뉴스룸",
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"성착취물로 번 돈 환수"…판매자 차량 등 처분금지 결정 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['늘어난 택배쓰레기, 분리수거도 없이 마구…"환경 악영향" / JTBC 뉴스룸',
#   '2:11',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['민주당 "전국민 고용보험 단계적 접근 필요" 속도 조절 / JTBC 뉴스룸',
#   '2:06',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 574회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['"재난지원금, 우리 카드사로" 유치경쟁 과열…정부 \'제동\' / JTBC 뉴스룸',
#   '1:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['트럼프 수행비서 이어 펜스·이방카 측근도 확진…백악관 비상 / JTBC 뉴스룸',
#   '3:14',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.1천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['13일 등교 개학은?…정부 "연기 거론 시기상조, 상황 주시" / JTBC 뉴스룸',
#   '0:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 733회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["클럽 풍선효과? 이태원 한산해졌지만 강남 '인파 북적' / JTBC 뉴스룸",
#   '2:18',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.9천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['카카오뱅크 상담 직원, 이태원 관련 확진…해당층 폐쇄 / JTBC 뉴스룸',
#   '0:50',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 470회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["마스크 안 쓴 채 수도권 활보…지역사회 'n차감염' 우려 / JTBC 뉴스룸",
#   '1:45',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 882회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["인천 정신병원 입원자 '이태원발 확진'…병원 출입통제 / JTBC 뉴스룸",
#   '3:17',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.2천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ['클럽 확진 외국인, 신촌주점도 가…당시 500여명 들락 / JTBC 뉴스룸',
#   '2:10',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["'이태원발 감염' 전국서 42명…당국, 방문 사실 신고 당부 / JTBC 뉴스룸",
#   '2:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.3천회',
#   '20시간 전',
#   '2020/05/10 16:52:08'],
#  ["2020년 5월 9일 (토) 뉴스룸 다시보기 - '이태원발' 감염 확산…전국서 42명",
#   '37:46',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 8만회',
#   '21시간 전',
#   '2020/05/10 16:52:08'],
#  ['[이슈정주행] "경영 세습 않겠다" 이재용 사과를 보는 시선들 / JTBC News',
#   '16:20',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.7천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[이슈정주행] "강력한 증거" 우한연구소 때리기…코로나발 미·중 갈등 격화 / JTBC News',
#   '6:46',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.8만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['밤샘토론 137회 - "정치 혁신, 세대교체가 답인가?" (2020.05.08)',
#   '2:16:20',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.7만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['"기부금 불투명" 이용수 할머니 비판에 윤미향 "기억 왜곡" / JTBC 정치부회의',
#   '2:45',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 9.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['조국 전 장관, 언론 향해 "반대 심문 내용도 보도해달라" / JTBC 정치부회의',
#   '1:57',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5.3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[뉴스룸 모아보기] 처음 법정 선 조국 "지치지 않고 싸울 것" / JTBC News',
#   '7:36',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["[뉴스룸 모아보기] 클럽발 집단감염 비상…젊은층 '무증상 감염' 복병 / JTBC News",
#   '12:09',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['5월 8일 (금) 뉴스룸 엔딩곡 (BGM : Teach Me Tonight - James Taylor) / JTBC News',
#   '0:52',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 830회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['정부 "8일 오후 8시부터 한 달간 전국 유흥시설 \'운영자제령\'" / JTBC 뉴스룸',
#   '2:37',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["2020년 5월 8일 (금) 뉴스룸 다시보기 - 집단감염, 새로운 '뇌관'…이태원 클럽",
#   '1:26:42',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 9.6만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["전 세계가 주목한 'K리그 개막전'…36개국서 생중계 / JTBC 뉴스룸",
#   '2:15',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'수업 중 성희롱 발언' 교사 2명 벌금 700만원 / JTBC 뉴스룸",
#   '0:44',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 966회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['불길 치솟는 현장서 입주민 대피 도운 경찰관 / JTBC 뉴스룸',
#   '0:43',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 856회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["전두환이 쓴 현충원 현판 '안중근 글씨'로 교체 / JTBC 뉴스룸",
#   '0:39',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.2천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'삼성물산 합병 의혹' 장충기 전 차장 재소환 / JTBC 뉴스룸",
#   '0:42',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 323회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['주민 20여 명도 위중…LG화학 "2차 가스 누출 없어" / JTBC 뉴스룸',
#   '2:20',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 698회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["이용수 할머니 비판에…정의연, '영수증' 공개하며 해명 / JTBC 뉴스룸",
#   '2:10',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.9천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["하늘길 좁힌 중국…창고엔 두 달째 '발 묶인 화물' / JTBC 뉴스룸",
#   '1:48',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.1천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'매장 내 식사금지'에 격분…미 맥도날드서 총기난사 / JTBC 뉴스룸",
#   '0:41',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.9천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['트럼프, 보좌 직원 확진에 "용암 분출하듯 분노" / JTBC 뉴스룸',
#   '1:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.7만회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["비닐 천막 너머 손끝 맞대고…어버이날 '애틋한 상봉' / JTBC 뉴스룸",
#   '1:56',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 587회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['대구시, 신천지 상대로 손배소 준비…"이만희 포함" / JTBC 뉴스룸',
#   '0:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 754회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['재난지원금 쓰려면 10% 웃돈?…암행단속에 딱 걸려 / JTBC 뉴스룸',
#   '2:01',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["1조원대 '방사광가속기' 청주로…경제 파급효과 수조원 / JTBC 뉴스룸",
#   '2:13',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.5천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["국민개헌발안제, 본회의서 '투표 불성립'…자동 폐기 / JTBC 뉴스룸",
#   '0:46',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 856회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["민주당 당원, 시민당과 '합당' 지지…한국당은 독자노선? / JTBC 뉴스룸",
#   '2:17',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 994회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['주호영 "과거 \'세월호 교통사고\' 발언, 소신에 변함 없다" / JTBC 뉴스룸',
#   '1:53',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.9천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] "강한 야당 만들 것"…주호영 통합당 새 원내대표 (2020.05.08 / JTBC 뉴스룸)',
#   '4:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 594회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'1100억원 사드 운영비' 계산 끝낸 미국…분담금 압박? / JTBC 뉴스룸",
#   '1:43',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.5천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['방위비 13억달러 요구하며 트럼프 "이미 합의" 주장 / JTBC 뉴스룸',
#   '1:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['정경심 재판부, 추가 구속영장 발부 안 해…10일 밤 석방 / JTBC 뉴스룸',
#   '1:54',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 864회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["법정 밖에선 조국 규탄 시위자-지지자들 간 '실랑이' / JTBC 뉴스룸",
#   '2:35',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 555회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'유재수 감찰' 중단 vs 종결…검찰-조국 측, 치열한 공방 / JTBC 뉴스룸",
#   '1:51',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 550회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['조국 전 장관 첫 재판…"법원의 시간, 지치지 않고 싸울 것" / JTBC 뉴스룸',
#   '2:16',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 778회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['이태원 클럽, 4~5일에 또 다른 확진자…접촉자 추적 어떻게? / JTBC 뉴스룸',
#   '4:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 5천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["직장 동료도 확진, 건물 통째 폐쇄…'클럽발' 일파만파 / JTBC 뉴스룸",
#   '1:38',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['부산 클럽 확진자 땐 추가감염 없었는데…뭐가 달랐나 / JTBC 뉴스룸',
#   '1:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.4천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'이태원 클럽' 방문자만 1500명 넘어…집단감염 '새 뇌관' / JTBC 뉴스룸",
#   '2:22',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["2020년 5월 8일 (금) 정치부회의 다시보기 - '용인 확진자' 관련 감염자 속출…방역 비상",
#   '1:10:58',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 7.8천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["대전 현충원 '전두환 현판' 철거…역사 바로세우기 / JTBC 정치부회의",
#   '3:29',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.3천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['김태년 "일하는 국회 만들 것…법사위, 제 위치로" / JTBC 정치부회의',
#   '7:25',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['미래통합당 신임 원내대표 주호영 선출 / JTBC 정치부회의',
#   '5:59',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 612회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ["'용인 확진자' 관련 감염자 속출…방역 비상 / JTBC 정치부회의",
#   '3:40',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1천회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[답하겠쏘라] 직장 내 성추행 왜 일어날까?｜JTBC 소셜라이브 Q&A 25탄',
#   '5:26',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 893회',
#   '1일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전] 김정은, 시진핑에 "방역 성공 축하"…해석은? (2020.05.08 / JTBC 뉴스ON)',
#   '4:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.1천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전] 트럼프, 또 방위비 압박?…일방적 '땡큐 코리아' (2020.05.08 / JTBC 뉴스ON)",
#   '5:41',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 2.5천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전] 위성정당의 '딴마음'?…국민의당과 연합설 '솔솔' (2020.05.08 / JTBC 뉴스ON)",
#   '8:14',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.3천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전] 새 원내사령탑에 김태년-주호영…21대 국회 전망은? (2020.05.08 / JTBC 뉴스ON)',
#   '22:08',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 4.2천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전 H/L] 취임 3주년 앞둔 문 대통령…지지율 '고공행진' / JTBC 뉴스ON",
#   '2:10',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.6만회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전 H/L] 김종배 "이낙연 발언, 오히려 \'겸손\'으로 해석할 수도" / JTBC 뉴스ON',
#   '4:37',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1.9천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["[라이브썰전 H/L] '슈퍼 여당' 원내대표 김태년…당청 관계 전망은? / JTBC 뉴스ON",
#   '7:23',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 253회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[라이브썰전 H/L] 통합당 새 원내대표 주호영…김종배 "마구잡이 투쟁 없을 것" / JTBC 뉴스ON',
#   '5:07',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 818회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['[인터뷰] 황운하 "공수처 취지는 검찰개혁…그래서 윤석열이 1호 수사대상 거론" / JTBC 뉴스ON',
#   '14:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 10만회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ["법원, 정경심 '구속 연장' 불가 결정…11일 0시 석방  / JTBC 뉴스ON",
#   '1:47',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 3.4천회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['첫 재판 나온 조국 "검찰 왜곡 하나하나 반박…지치지 않고 싸울 것"  / JTBC 뉴스ON',
#   '1:50',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 930회',
#   '2일 전',
#   '2020/05/10 16:52:08'],
#  ['한국의 \'익명 선행\' 원하는 일본? "선의로 받자" 언론 기고 논란  / JTBC 뉴스ON',
#   '1:22',
#   'JTBC News',
#   '구독자 132만명',
#   '조회수 1만회',
#   '2일 전',
#   '2020/05/10 16:52:08']]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-96-fdd47c167f96> in <module>
#       7     roww = []
#       8     roww.append(title[i])
# ----> 9     roww.append(video_time[i].strip())
#      10     roww.append(chennel)
#      11     roww.append(sub_num)
#
# IndexError: list index out of range

# %%
import csv

csvfile = open("C:/Users/kjh96/Github/crawling_JTBC.csv","w",newline="")
csvwriter = csv.writer(csvfile)
for row in youtube_video_list:
    csvwriter.writerow(row)
csvfile.close()
# Out:
# 98
# 96
# 116
# 101
# 107
# 129
# 117
# 113
# 113
# 105
# 102
# 100
# 106
# 135
# 110
# 111
# 126
# 111
# 107
# 108
# 108
# 108
# 111
# 107
# 112
# 105
# 105
# 105
# 104
# 107
# 110
# 110
# 113
# 119
# 113
# 114
# 111
# 111
# 113
# 130
# 113
# 115
# 102
# 100
# 96
# 99
# 97
# 107
# 105
# 101
# 101
# 104
# 101
# 104
# 101
# 102
# 102
# 105
# 110
# 122
# 105
# 104
# 106
# 101
# 107
# 110
# 107
# 105
# 101
# 107
# 118
# 102
# 105
# 94
# 97
# 104
# 124
# 124
# 122
# 124
# 112
# 121
# 112
# 122
# 122
# 108
# 116
# 114

# %%
import pandas as pd
jtbc = pd.read_csv("C:/Users/kjh96/Github/crawling_JTBC.csv", encoding="CP949", header=None)
jtbc.columns = ["name","time_play","channel","num_sub","num_view","time_pub","time"] # df.rename(column = {전:후, 전:후})
jtbc
# Out:
#                                                  name time_play    channel  \
# 0                 제주서 이태원 방문 코로나19 확진자 발생 / JTBC News      0:36  JTBC News
# 1                   이태원 클럽 방문자 7222명 전수조사 / JTBC News      0:40  JTBC News
# 2   [취임 3주년 질의응답] "남북·북미간 신뢰·대화의지 확인하고 있어" / JTBC ...      5:56  JTBC News
# 3               [문 대통령 취임 3주년 연설] 5월 10일 (일) 뉴스특보 풀영상     47:53  JTBC News
# 4          [취임 3주년 질의응답] 기자 "디지털화, 일자리 빼앗는단 우려도 있는데…"      3:35  JTBC News
# ..                                                ...       ...        ...
# 83  [라이브썰전 H/L] 통합당 새 원내대표 주호영…김종배 "마구잡이 투쟁 없을 것" ...      5:07  JTBC News
# 84  [인터뷰] 황운하 "공수처 취지는 검찰개혁…그래서 윤석열이 1호 수사대상 거론" /...     14:47  JTBC News
# 85       법원, 정경심 '구속 연장' 불가 결정…11일 0시 석방  / JTBC 뉴스ON      1:47  JTBC News
# 86  첫 재판 나온 조국 "검찰 왜곡 하나하나 반박…지치지 않고 싸울 것"  / JTBC...      1:50  JTBC News
# 87  한국의 '익명 선행' 원하는 일본? "선의로 받자" 언론 기고 논란  / JTBC ...      1:22  JTBC News
#
#       num_sub   num_view time_pub                 time
# 0   구독자 132만명  조회수 2.2천회    5시간 전  2020/05/10 16:52:08
# 1   구독자 132만명  조회수 2.8천회    5시간 전  2020/05/10 16:52:08
# 2   구독자 132만명   조회수 517회    5시간 전  2020/05/10 16:52:08
# 3   구독자 132만명  조회수 2.9만회    5시간 전  2020/05/10 16:52:08
# 4   구독자 132만명    조회수 1천회    5시간 전  2020/05/10 16:52:08
# ..        ...        ...      ...                  ...
# 83  구독자 132만명   조회수 818회     2일 전  2020/05/10 16:52:08
# 84  구독자 132만명   조회수 10만회     2일 전  2020/05/10 16:52:08
# 85  구독자 132만명  조회수 3.4천회     2일 전  2020/05/10 16:52:08
# 86  구독자 132만명   조회수 930회     2일 전  2020/05/10 16:52:08
# 87  구독자 132만명    조회수 1만회     2일 전  2020/05/10 16:52:08
#
# [88 rows x 7 columns]

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

import numpy as np
import pandas as pd
import scipy

# import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(colorscale='plotly', world_readable=True)

# Extra options
pd.options.display.max_rows = 30
pd.options.display.max_columns = 25

# Show all code cells outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# Online features (plotly.plotly) moved to chart-studio package
import chart_studio.plotly as py

import os
from IPython.display import Image, display, HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 숫자만 추출 후 숫자형으로 변환 
crawling['comment_num_new']= crawling['comment_num'].str.replace("," , "") # "," 제외
crawling['comment_num_fin'] = crawling['comment_num_new'].str.extract('(\d+)')
crawling['comment_num_fin'] = pd.to_numeric(crawling['comment_num_fin'])

crawling['view_new'] = crawling['view'].str.extract('(\d+)')
crawling['view_fin'] = pd.to_numeric(crawling['view_new'])

# %%
df = crawling
df.head(3)
# Out:
#                            name comment_num  view likes_num comment_num_new  \
# 0             순한 맛으로 끓인 '홍합 라면'     댓글 365개  11만회     2.4천개         댓글 365개
# 1            토마토 달걀 볶음! 드셔보셨나요?   댓글 1,112개  46만회     1.1만개        댓글 1112개
# 2  정말 간단해요! 안주로 안성맞춤인 시금치베이컨볶음!     댓글 363개  18만회       4천개         댓글 363개
#
#    comment_num_fin view_new  view_fin
# 0              365       11        11
# 1             1112       46        46
# 2              363       18        18

# %%
### Line control
@interact
def show_articles_more_than(column=['comment_num_fin','view_fin'], x=(-100,100,10)):
    return df.loc[df[column] > x]
# Out:
# interactive(children=(Dropdown(description='column', options=('comment_num_fin', 'view_fin'), value='comment_n…

# %%
### Correlation

@interact
def correlation(column1 = list(df.select_dtypes('number').columns), 
                 column2 = list(df.select_dtypes('number').columns)) :
    print(f"Correlation : {df[column1].corr(df[column2])}")

# %%
### Graph
import cufflinks as cf

@interact
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:],
                 theme=list(cf.themes.THEMES.keys()), 
                 colorscale=list(cf.colors._scales_names.keys())):
    
    df.iplot(kind='scatter', x=x, y=y, mode='markers', 
             xTitle=x.title(), yTitle=y.title(), 
             text='name',
             title=f'{y.title()} vs {x.title()}',
            theme=theme, colorscale=colorscale)

# %%
df_new = crawling[0:3]
df_new

# %%
df_new["start_date"] = ""
df_new["end_date"] = ""

df_new["start_date"][0] = "2018-01-01"
df_new["start_date"][1] = "2018-02-01"
df_new["start_date"][2] = "2018-03-01"

df_new["end_date"][0] = "2019-01-01"
df_new["end_date"][1] = "2019-02-01"
df_new["end_date"][2] = "2019-03-01"

df_new

# %%
# Create interactive version of function with DatePickers
interact(start_date=widgets.DatePicker(value=pd.to_datetime('2018-01-01')),
        end_date=widgets.DatePicker(value=pd.to_datetime('2019-01-01')))

# %%
# Create widgets
directory = widgets.Dropdown(options=['images', 'nature', 'assorted'])
images = widgets.Dropdown(options=os.listdir(directory.value))

# Updates the image options based on directory value
def update_images(*args):
    images.options = os.listdir(directory.value)

# Tie the image options to directory value
directory.observe(update_images, 'value')

# Show the images
def show_images(fdir, file):
    display(Image(f'{fdir}/{file}'))

_ = interact(show_images, fdir=directory, file=images)
